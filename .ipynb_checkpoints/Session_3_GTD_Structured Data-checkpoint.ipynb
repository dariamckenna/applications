# %% [markdown]
# # Dealing with Structured Data- Global Terrorism Database

# %% [markdown]
# ### Thanks to Samuel Capps (6980 2020 QTR 1) for identifying this dynamic

# %%
# Import libraries to aid your analysis
import pandas as pd #pandas places ones data in tables format
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Let's look at the data

# %%
pwd
# Out:
# '/home/EDSE-dariamck-workspace/MST688/applications'

# %%
# Datasheet was downbloaed form GTD and being read in form a local .csv file
GTD = pd.read_excel(r"/home/EDSE-dariamck-workspace/GTD_db/globalterrorismdb_0919dist.xlsx")
                  #encoding = "ISO-8859-1", engine = 'python') 
# had some issues with the data types, had to search online for example to read properly
GTD.head() # see the structure--default is first five rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Pandas library has a describe function to apply algorithms against the data...
# whether approriate or not
GTD.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.914640e+05  191464.000000  191464.000000  191464.000000
# mean   2.003486e+11    2003.420136       6.462510      15.507688
# std    1.334949e+09      13.349405       3.388515       8.807727
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991083e+11    1991.000000       4.000000       8.000000
# 50%    2.010031e+11    2010.000000       6.000000      15.000000
# 75%    2.015013e+11    2015.000000       9.000000      23.000000
# max    2.018123e+11    2018.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  191464.000000  191464.000000  191464.000000  186884.000000
# mean        0.047476     131.290446       7.205167      23.462121
# std         0.212656     112.058063       2.923811      18.405309
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       6.000000      11.274796
# 50%         0.000000      98.000000       7.000000      31.445840
# 75%         0.000000     160.000000      10.000000      34.621521
# max         1.000000    1004.000000      12.000000      74.633553
#
#            longitude    specificity  ...     ransomamt   ransomamtus  \
# count  186883.000000  191463.000000  ...  1.416000e+03  6.230000e+02
# mean       28.902126       1.458172  ...  3.057619e+06  5.227734e+05
# std        57.231040       0.991536  ...  2.951278e+07  6.730057e+06
# min      -176.176447       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%         7.052742       1.000000  ...  0.000000e+00  0.000000e+00
# 50%        43.471427       1.000000  ...  1.500000e+04  0.000000e+00
# 75%        68.783077       1.000000  ...  4.000000e+05  0.000000e+00
# max       179.366667       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  8.380000e+02    611.000000    12045.000000  11454.000000
# mean   6.961705e+05    217.004910        4.643005    -29.816309
# std    9.792528e+06   2796.042504        2.034429     65.183303
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2912.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  191464.000000  191464.000000  191464.000000  191464.000000
# mean       -4.521727      -4.439247       0.088951      -3.930582
# std         4.543713       4.639931       0.556741       4.689726
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#Identifies the total number of rows
len(GTD)
# Out:
# 191464

# %%
#provides information about the dataframe
GTD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191464 entries, 0 to 191463
# Columns: 135 entries, eventid to related
# dtypes: datetime64[ns](1), float64(53), int64(24), object(57)
# memory usage: 197.2+ MB

# %%
#See the titles of the 135 columns
for col in GTD.columns:
    print(col)
# !!!! Look in the GTD_Codebook to get more information about each column !!!!
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# # Problem 1: Change the Country (do after going through the whole notebook)

# %%
# reduce the dataframe down to just the philippines
country = GTD[GTD["country_txt"]=="Greece"] # store the information in an object called country
#you can change Philippines to any country in the dataset
country.head(10) #by putting in 10 I changed the default setting of 1st 5 rows to 1st 10 rows

#Changed country from Phillipines to Greece
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 3     197001000002   1970       1     0        NaN         0        NaT
# 421   197007220001   1970       7    22        NaN         0        NaT
# 490   197009020001   1970       9     2        NaN         0        NaT
# 882   197105150001   1971       5    15        NaN         0        NaT
# 1463  197208290002   1972       8    29        NaN         0        NaT
# 1650  197212070001   1972      12     7        NaN         0        NaT
# 1698  197301070001   1973       1     7        NaN         0        NaT
# 1699  197301070002   1973       1     7        NaN         0        NaT
# 1738  197302020002   1973       2     2        NaN         0        NaT
# 1805  197303220001   1973       3    22        NaN         0        NaT
#
#       country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 3          78      Greece       8  ...      NaN    NaN    NaN     NaN
# 421        78      Greece       8  ...      NaN    NaN    NaN     NaN
# 490        78      Greece       8  ...      NaN    NaN    NaN     NaN
# 882        78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1463       78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1650       78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1698       78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1699       78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1738       78      Greece       8  ...      NaN    NaN    NaN     NaN
# 1805       78      Greece       8  ...      NaN    NaN    NaN     NaN
#
#           dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 3             PGIS       -9        -9        1       1      NaN
# 421   Hijacking DB       -9        -9        0      -9      NaN
# 490           PGIS       -9        -9        1       1      NaN
# 882           PGIS       -9        -9        1       1      NaN
# 1463          PGIS        0         1        1       1      NaN
# 1650          PGIS        0         1        1       1      NaN
# 1698          PGIS       -9        -9        1       1      NaN
# 1699          PGIS       -9        -9        1       1      NaN
# 1738          PGIS       -9        -9        1       1      NaN
# 1805          PGIS        0         1        1       1      NaN
#
# [10 rows x 135 columns]

# %% [markdown]
# ### Let's deep dive in a country

# %%
attacks_by_group = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in country.iterrows(): 
    if row["gname"]  in attacks_by_group.keys():
        attacks_by_group[row["gname"]] += 1 #if group is in the dictionary add 1 attack
    else:
        attacks_by_group[row["gname"]] = 1 #add group name to dictionary if not in dictionary

attacks_by_group
# Out:
# {'Unknown': 609,
#  'Arabs': 1,
#  'Popular Revolutionary Resistance Group': 1,
#  'Resistance, Liberation and Independence Organization (AAA)': 1,
#  'Greek Anti-Dictatorial Youth (EAN)': 1,
#  'National Youth Resistance Organization': 1,
#  'Black September': 1,
#  "People's Resistance Organized Army": 1,
#  'Popular Resistance Sabotage Group': 2,
#  'Popular Front for the Liberation of Palestine, Gen Cmd (PFLP-GC)': 1,
#  "Revolutionary People's Struggle (ELA)": 88,
#  'Palestine Liberation Organization (PLO)': 1,
#  'November 17 Revolutionary Organization (N17RO)': 112,
#  'First of October Antifascist Resistance Group (GRAPO)': 1,
#  'Kentavros': 1,
#  'Armenian Secret Army for the Liberation of Armenia': 3,
#  'Greek National Socialist Organization': 3,
#  'Khristos Kasimis': 5,
#  'Fighting Popular Rally': 7,
#  'Greek Popular Resistance': 1,
#  'Qaddafi loyalists': 1,
#  'Left-wing extremists': 4,
#  'Revolutionary Popular Left': 7,
#  'October-80': 3,
#  'Autonomous Resistance': 3,
#  'Dev Sol': 1,
#  'Irish Republican Army (IRA)': 1,
#  'Revolutionary Anti-Capitalist Initiative': 2,
#  'Popular Front for the Liberation of Palestine (PFLP)': 1,
#  'Blue Archer Group': 1,
#  'May 15 Organization for the Liberation of Palestine': 1,
#  'Iconoclastic Nihilists': 1,
#  '4 August National Organization': 2,
#  'Autonomy (Greece)': 1,
#  'Revolutionary Solidarity': 4,
#  'Group for Martyred Isam as-Sartawi': 2,
#  'Shia Muslim extremists': 1,
#  'Northern Epirus Liberation Front (MAVI)': 1,
#  'Movement for Rebuilding Fatah': 1,
#  'Abu Nidal Organization (ANO)': 3,
#  'Yellow Organization of Air Force Officers': 3,
#  'Turks': 1,
#  'Lebanese National Resistance Front': 1,
#  'Revolutionary Organization of Socialist Muslims': 1,
#  'Libyan': 1,
#  'National Front for the Salvation of Libya': 1,
#  'November 21 Organization': 5,
#  'National Front (Greece)': 1,
#  'Black September II': 3,
#  'Youths': 1,
#  'Hezbollah': 2,
#  '7 April Libyan Organization': 3,
#  'Wild Geese of the Cities': 1,
#  'Revolutionary Militant Left organization': 1,
#  'Arab Revolutionary Cells': 1,
#  'Anarchists': 55,
#  'The Illegal Fisherman of the Night': 1,
#  'Suicide Squad': 3,
#  'Revolutionary Cells': 1,
#  'Marxists': 1,
#  'Anti-Authority Group (Greece)': 13,
#  'Social Resistance': 9,
#  '1 May': 10,
#  'Cells for Solidarity Against Authority': 1,
#  'Anarchist Solidarity': 2,
#  'Mikhail Kaltezas Anarchist Organization': 1,
#  'Popular Rage': 4,
#  "People's Rebellion": 1,
#  'Kurdish Dissidents': 1,
#  'May 36': 1,
#  "Greek Anarchists' Union": 2,
#  'Anti-Fascist Action': 1,
#  'Furious Rebellion': 1,
#  "Kurdistan Workers' Party (PKK)": 2,
#  'Arsonists': 1,
#  'Turks of Western Thrace': 1,
#  'Anti-Establishment Nucleus': 2,
#  'Ethiopians': 1,
#  'Nihilists Faction': 2,
#  'Fighting Guerrilla Formation': 5,
#  'Children of November': 2,
#  'Revolted Persons of the Polytech School': 1,
#  'Revolutionary Nuclei': 12,
#  'Massive escape': 1,
#  'Revolutionary Struggle': 24,
#  'May 15': 1,
#  'Conscientious Arsonists (CA)': 5,
#  'May 98': 2,
#  'Arsonists for Social Cohesion': 3,
#  'Fight Against Authority': 1,
#  'Support of Ocalan-The Hawks of Thrace': 1,
#  'Red Line': 1,
#  'Anti-State Proletarian Nuclei': 1,
#  'Friendly Company': 1,
#  'Anti-State Action': 3,
#  'Anti-Capitalist Action': 1,
#  'Anarchist Faction': 2,
#  'Erotic Anti-authority Cells': 1,
#  'Last Generation': 1,
#  'Black Star': 7,
#  'Anarchist Struggle': 1,
#  'Anarchists Attack Team': 1,
#  'Revolutionary Violence Units': 1,
#  'Anarchist Squad': 1,
#  'Group of Carlo Giuliani': 1,
#  'Anarchist Liberation Brigade': 1,
#  'Popular Resistance (Laiki Antistasi)': 2,
#  'New Revolutionary Popular Struggle (NELA)': 1,
#  'Rabid Brothers of Giuliani': 1,
#  'Enraged Revolutionaries': 1,
#  'The War That Was Never Declared': 1,
#  'Popular Revolutionary Action': 1,
#  'Resistance Cell': 1,
#  'Anti-State Justice': 5,
#  'Revolutionary Action of Liberation': 4,
#  'Solidarity with imprisoned members of Action Directe (AD)': 2,
#  'Athens and Thessaloniki Arsonist Nuclei': 8,
#  'Conspiracy of Cells of Fire': 50,
#  'Armed Revolutionary Action (ENEDRA)': 2,
#  'Forbidden Blockade (Greece)': 1,
#  'Anti-Democratic Struggle': 2,
#  'Gangs of Conscience': 2,
#  'Popular Will (Greece)': 3,
#  'Incendiary Committee of Solidarity for Detainees': 1,
#  'Sect of Revolutionaries (Greece)': 3,
#  'Revolutionary Liberation Action (Epanastatiki Apelevtherotiki Drasi) - Greece': 3,
#  'Alexandros Grigoropoulos Anarchist Attack Group': 1,
#  'Attack Teams for the Dissolution of the Nation (Greece)': 3,
#  'Deniers of Holidays': 1,
#  'Zero Tolerance': 5,
#  'Illuminating Paths of Solidarity': 6,
#  'Council for the Destruction of Order': 1,
#  'Anarchist Action (CA / United States)': 1,
#  'Black and Red Anarchist and Anti-Authoritarians Initiative (Greece)': 1,
#  'Revolutionary Continuity': 1,
#  'Rebellious Group Lambros Foundas': 1,
#  'Groups for Dissemination of Revolutionary Theory and Action': 1,
#  'Urban Guerrilla War': 1,
#  'International Revolutionary Front': 2,
#  'Proletariat Self-defense Groups': 4,
#  'Militant Minority (Greece)': 7,
#  'Informal Anarchist Federation': 5,
#  'Group of Popular Fighters': 9,
#  'Golden Dawn': 2,
#  'Wild Freedom': 1,
#  'Angry Brigade': 1,
#  'Overall Deniers of Joining the Existing': 3,
#  'Epanastatiki Anatropi (Revolutionary Overthrow)': 1,
#  'Detonators of Social Uprisings': 1,
#  'Unsubordinated Desires': 1,
#  'Powers of the Revolutionary Arc': 1,
#  "Militant People's Revolutionary Forces": 1,
#  'Organization for Revolutionary Self Defense': 5,
#  'Anarchist Anti-Capitalist Action Group': 1,
#  'Proletarian Assault Group': 1,
#  'Anarchist Attack Consortium': 1,
#  'Anarchist Commando Nestor Makhno Group': 1,
#  'Nihilistic Patrol and Neighborhood Arsonists': 1,
#  'Earth Liberation Front (ELF)': 1,
#  'Rubicon (Rouvikonas)': 10,
#  'Les Casseurs': 1,
#  'Unrepentant Anarchists': 1,
#  'Lone Wolves of Radical, Autonomous, Militant National Socialism': 1,
#  'Cells of Direct Attack - Living Waste Group': 1,
#  'Residents and regulars of Exarchia': 1,
#  'Apella': 1,
#  'Neo-Fascist extremists': 3,
#  'Anarchist Collective of Kallithea-Moschato': 1,
#  'Crypteia': 4,
#  'Minorities of Metropolitan Attacks': 2,
#  'Armed Revolutionary Forces': 1,
#  'Muslim extremists': 1,
#  'Iconoclastic Sect': 1}

# %%
# Make X and Y axis for a bar chart plotting attacks
groups = list(attacks_by_group.keys())
attacks = list(attacks_by_group.values())

# %%
#Sort from smallest to largest
sorted_groups = sorted(groups, key=lambda x: attacks[groups.index(x)])
sorted_attacks = sorted(attacks)

# %% [markdown]
# # Problem 2: For any country only do plot the top 5 groups (Hint: Use list slicing e.g sorted_attacks[-10:])

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_groups, plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_groups, width=0.5, bottom=0,
       top= sorted_attacks[-5:], color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('top', 5), ('x', 173)

# %%
show(p)
# Out:
#   <div class="bk-root" id="2c1152d3-1d23-41f0-834a-45f3ec301a5c" data-root-id="1002"></div>

# %% [markdown]
# ## Now lets plot the attacks in a map

# %%
#Imports necessary aspects of Bokeh for plotting on a map
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')

# %%
# Take the data reduced to a country and get the lat/long of the attacks and the name of the group
country_map = country[["latitude", 'longitude', 'gname']]

#see the data this time first 7 rows
country_map.head(7)
# Out:
#        latitude  longitude                                              gname
# 3     37.997490  23.762728                                            Unknown
# 421   37.997490  23.762728                                              Arabs
# 490   37.997490  23.762728                                            Unknown
# 882   37.742578  20.896502                                            Unknown
# 1463  37.997490  23.762728             Popular Revolutionary Resistance Group
# 1650  37.997490  23.762728  Resistance, Liberation and Independence Organi...
# 1698  37.997490  23.762728                                            Unknown

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
map_dict = {} # empty dictionary to track group attacks by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing


# Iterate through tables and associate group with lat/long
for idx, row in country_map.iterrows():    
    if row['gname'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['gname'] in nan_count.keys(): 
                nan_count[row['gname']] += 1 
            else: 
                nan_count[row['gname']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['gname']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']] =[[point[0],point[1]]]
        
#This tells how many attacks we are losing
nan_count
# Out:
# {'Unknown': 2,
#  'Greek National Socialist Organization': 1,
#  'Blue Archer Group': 1,
#  '1 May': 1,
#  "Revolutionary People's Struggle (ELA)": 1}

# %% [markdown]
# # Problem 3: Print the top 5 groups from the map_dict structure

# %%
num_attacks = []
for val in map_dict.values():
    num_attacks.append(len(val))
sorted(num_attacks)[-5:]
# Out:
# [50, 55, 87, 112, 607]

# %%
for num in sorted(num_attacks)[-5:]:
    for k,v in map_dict.items():
        if len(v) == num:
            print(k)

# since I went took the last 5 items and sorted from smallest to largest, the group with the most attacks appears last
# Out:
# Conspiracy of Cells of Fire
# Anarchists
# Revolutionary People's Struggle (ELA)
# November 17 Revolutionary Organization (N17RO)
# Unknown

# %% [markdown]
# # Problem 4: Change the map to show a new country.
# ## You can get the lat/long for different places here : https://www.latlong.net/

# %%
pts = [(36.00,20.00), (41.50,24.00)] #Changed lat and long to coinced with Greece
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)

# %%
NPA_x = []
NPA_y = []
for pt in map_dict["Unknown"]:
    NPA_x.append(pt[0])
    NPA_y.append(pt[1])

# %%
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPA_x, y = NPA_y, color= "firebrick")

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="db9a063c-63f6-485e-9dc3-8bdca5ade741" data-root-id="1219"></div>
