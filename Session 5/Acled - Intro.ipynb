# %%
#import libraries
import requests
from datetime import datetime as dt
from datetime import timedelta
import pandas as pd

# %%
# get events from n days ago
look_back_days = 45

days_ago_dte = dt.now() - timedelta(days=look_back_days)
print (days_ago_dte, type(days_ago_dte)) #gives us a time object
days_ago = days_ago_dte.strftime('%Y-%m-%d')
print (days_ago, type(days_ago)) #converts the time object to string so it can be based into the request

# you can limit the number of records that return from the API
# set to 0 for no limit
limit = 10

api_url = 'https://api.acleddata.com/acled/read?terms=accept&event_date={}&event_date_where=%3E=&limit={}'.format(days_ago, limit)
print (api_url, type(api_url)) #creates request according to ACLED format specifications - p. 13
# Out:
# 2020-08-08 19:35:33.678998 <class 'datetime.datetime'>
# 2020-08-08 <class 'str'>
# https://api.acleddata.com/acled/read?terms=accept&event_date=2020-08-08&event_date_where=%3E=&limit=10 <class 'str'>

# %%
response = requests.get(api_url) # Reality I spent 45 minutes figuring out why my search kept failing 
                                # and learned I had an older user guide that didn't include terms=accept 
data = response.json()
data.keys()
# Out:
# dict_keys(['status', 'success', 'last_update', 'count', 'messages', 'data', 'filename'])

# %%
data['status'], data['success'], data['count'] # see the refrenet for API status codes
# Out:
# (200, True, 10)

# %%
data_new = data['data'] #getting just the data 
rows = len(data_new)
print ('ACLED API returned {} rows'.format(rows))
# Out:
# ACLED API returned 10 rows

# %%
#convert it into an pandas data frame
acled_data = pd.DataFrame.from_dict(data_new)
acled_data
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  7231586  804      UKR40539            40539  2020-09-19  2020
# 1  7231583  804      UKR40541            40541  2020-09-19  2020
# 2  7231577  300       GRC2226             2226  2020-09-19  2020
# 3  7231567  643       RUS5045             5045  2020-09-19  2020
# 4  7231566  804      UKR40538            40538  2020-09-19  2020
# 5  7231564  643       RUS5043             5043  2020-09-19  2020
# 6  7231563  643       RUS5041             5041  2020-09-19  2020
# 7  7231555  643       RUS5042             5042  2020-09-19  2020
# 8  7231538  643       RUS5047             5047  2020-09-19  2020
# 9  7231537  643       RUS5040             5040  2020-09-19  2020
#
#   time_precision event_type             sub_event_type                actor1  \
# 0              1   Protests           Peaceful protest  Protesters (Ukraine)
# 1              1   Protests           Peaceful protest  Protesters (Ukraine)
# 2              1   Protests           Peaceful protest   Protesters (Greece)
# 3              1   Protests           Peaceful protest   Protesters (Russia)
# 4              1   Protests           Peaceful protest  Protesters (Ukraine)
# 5              1   Protests           Peaceful protest   Protesters (Russia)
# 6              1   Protests           Peaceful protest   Protesters (Russia)
# 7              1   Protests  Protest with intervention   Protesters (Russia)
# 8              1   Protests           Peaceful protest   Protesters (Russia)
# 9              1   Protests           Peaceful protest   Protesters (Russia)
#
#    ...                   location latitude longitude geo_precision  \
# 0  ...                       Lviv  49.8407   24.0305             1
# 1  ...                     Odessa  46.4639   30.7386             1
# 2  ...               Thessaloniki  40.6436   22.9309             1
# 3  ...  St. Petersburg-Tsentralny  59.9324   30.3654             1
# 4  ...                       Kiev  50.4496   30.5224             1
# 5  ...                Novosibirsk  55.0415   82.9346             1
# 6  ...             Moscow-Central  55.7571   37.6173             1
# 7  ...             Moscow-Central  55.7571   37.6173             1
# 8  ...                Vladivostok  43.1211  131.9226             1
# 9  ...               Magnitogorsk  53.4186   59.0472             1
#
#                 source   source_scale  \
# 0  Tradition and Order          Other
# 1  Tradition and Order          Other
# 2           To Pontiki       National
# 3              Rosbalt       National
# 4         Right Sector          Other
# 5               RFE/RL  International
# 6               RFE/RL  International
# 7             OVD Info       National
# 8  Novosti Vladivostok    Subnational
# 9        Novaya Gazeta       National
#
#                                                notes fatalities   timestamp  \
# 0  On 19 September 2020, members of Traditions an...          0  1600804254
# 1  On 19 September 2020, members of Traditions an...          0  1600804254
# 2  On 19 September 2020, tens of solidarity prote...          0  1600804254
# 3  On 19 September 2020, about 100 people, includ...          0  1600804254
# 4  On 19 September 2020, members of Right Sector ...          0  1600804254
# 5  On 19 September 2020, about 100 people took pa...          0  1600804254
# 6  On 19 September 2020, an unspecified number of...          0  1600804254
# 7  On 19 September 2020, police detained at least...          0  1600804254
# 8  On 19 September 2020, about 30 people took par...          0  1600804254
# 9  On 19 September 2020, at least 15 people, incl...          0  1600804254
#
#   iso3
# 0  UKR
# 1  UKR
# 2  GRC
# 3  RUS
# 4  UKR
# 5  RUS
# 6  RUS
# 7  RUS
# 8  RUS
# 9  RUS
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Does this comport with what is the in the documentation?
