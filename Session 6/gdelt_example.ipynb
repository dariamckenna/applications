# %% [markdown]
# Adopted from GDELT Data Wrangle by James Houghton https://nbviewer.jupyter.org/github/JamesPHoughton/Published_Blog_Scripts/blob/master/GDELT%20Wrangler%20-%20Clean.ipynb

# %% [markdown]
# Additional GDELT resources:
#
#     GDELT library overview: https://colab.research.google.com/drive/1rnKEHKV1StOwGtFPsCctKDPTBB_kHOc_?usp=sharing
#
#     GDELT with big data: https://github.com/linwoodc3/gdeltPyR/wiki/Pulling-Large-GDELT-Data

# %% [markdown]
# # PART I: Get GDELT DATA FOR NIGER
#
#
# ### Get the GDELT index files

# %%
# PIKE HERE!!
# interested in Chinese Gov invovlement in South Africa
# Changed country code to SF and looked into codeType rather than eventType
# made a bar graph of instances by country fro ActionGeo_CountryType
# results are kind of garbage, and the Chinese weren't as involved as expected 
# tried to find average of AvgTone in articles

# %%
import requests
import lxml.html as lh

gdelt_base_url = 'http://data.gdeltproject.org/events/'

# get the list of all the links on the gdelt file page
page = requests.get(gdelt_base_url+'index.html') #Grab GDELT reference list which is by day
doc = lh.fromstring(page.content)
link_list = doc.xpath("//*/ul/li/a/@href") #Returns all the possible CSV files of GDELT data as a references list

# separate out those links that begin with four digits 
'''
Will extract just the days resulting in list like: 
['20200617.export.CSV.zip',
 '20200616.export.CSV.zip',
 '20200615.export.CSV.zip',...]
 Until 2015
'''

file_list = [x for x in link_list if str.isdigit(x[0:4])]
file_list
# Out:
# ['20201004.export.CSV.zip',
#  '20201003.export.CSV.zip',
#  '20201002.export.CSV.zip',
#  '20201001.export.CSV.zip',
#  '20200930.export.CSV.zip',
#  '20200929.export.CSV.zip',
#  '20200928.export.CSV.zip',
#  '20200927.export.CSV.zip',
#  '20200926.export.CSV.zip',
#  '20200925.export.CSV.zip',
#  '20200924.export.CSV.zip',
#  '20200923.export.CSV.zip',
#  '20200922.export.CSV.zip',
#  '20200921.export.CSV.zip',
#  '20200920.export.CSV.zip',
#  '20200919.export.CSV.zip',
#  '20200918.export.CSV.zip',
#  '20200917.export.CSV.zip',
#  '20200916.export.CSV.zip',
#  '20200915.export.CSV.zip',
#  '20200914.export.CSV.zip',
#  '20200913.export.CSV.zip',
#  '20200912.export.CSV.zip',
#  '20200911.export.CSV.zip',
#  '20200910.export.CSV.zip',
#  '20200909.export.CSV.zip',
#  '20200908.export.CSV.zip',
#  '20200907.export.CSV.zip',
#  '20200906.export.CSV.zip',
#  '20200905.export.CSV.zip',
#  '20200904.export.CSV.zip',
#  '20200903.export.CSV.zip',
#  '20200902.export.CSV.zip',
#  '20200901.export.CSV.zip',
#  '20200831.export.CSV.zip',
#  '20200830.export.CSV.zip',
#  '20200829.export.CSV.zip',
#  '20200828.export.CSV.zip',
#  '20200827.export.CSV.zip',
#  '20200826.export.CSV.zip',
#  '20200825.export.CSV.zip',
#  '20200824.export.CSV.zip',
#  '20200823.export.CSV.zip',
#  '20200822.export.CSV.zip',
#  '20200821.export.CSV.zip',
#  '20200820.export.CSV.zip',
#  '20200819.export.CSV.zip',
#  '20200818.export.CSV.zip',
#  '20200817.export.CSV.zip',
#  '20200816.export.CSV.zip',
#  '20200815.export.CSV.zip',
#  '20200814.export.CSV.zip',
#  '20200813.export.CSV.zip',
#  '20200812.export.CSV.zip',
#  '20200811.export.CSV.zip',
#  '20200810.export.CSV.zip',
#  '20200809.export.CSV.zip',
#  '20200808.export.CSV.zip',
#  '20200807.export.CSV.zip',
#  '20200806.export.CSV.zip',
#  '20200805.export.CSV.zip',
#  '20200804.export.CSV.zip',
#  '20200803.export.CSV.zip',
#  '20200802.export.CSV.zip',
#  '20200801.export.CSV.zip',
#  '20200731.export.CSV.zip',
#  '20200730.export.CSV.zip',
#  '20200729.export.CSV.zip',
#  '20200728.export.CSV.zip',
#  '20200727.export.CSV.zip',
#  '20200726.export.CSV.zip',
#  '20200725.export.CSV.zip',
#  '20200724.export.CSV.zip',
#  '20200723.export.CSV.zip',
#  '20200722.export.CSV.zip',
#  '20200721.export.CSV.zip',
#  '20200720.export.CSV.zip',
#  '20200719.export.CSV.zip',
#  '20200718.export.CSV.zip',
#  '20200717.export.CSV.zip',
#  '20200716.export.CSV.zip',
#  '20200715.export.CSV.zip',
#  '20200714.export.CSV.zip',
#  '20200713.export.CSV.zip',
#  '20200712.export.CSV.zip',
#  '20200711.export.CSV.zip',
#  '20200710.export.CSV.zip',
#  '20200709.export.CSV.zip',
#  '20200708.export.CSV.zip',
#  '20200707.export.CSV.zip',
#  '20200706.export.CSV.zip',
#  '20200705.export.CSV.zip',
#  '20200704.export.CSV.zip',
#  '20200703.export.CSV.zip',
#  '20200702.export.CSV.zip',
#  '20200701.export.CSV.zip',
#  '20200630.export.CSV.zip',
#  '20200629.export.CSV.zip',
#  '20200628.export.CSV.zip',
#  '20200627.export.CSV.zip',
#  '20200626.export.CSV.zip',
#  '20200625.export.CSV.zip',
#  '20200624.export.CSV.zip',
#  '20200623.export.CSV.zip',
#  '20200622.export.CSV.zip',
#  '20200621.export.CSV.zip',
#  '20200620.export.CSV.zip',
#  '20200619.export.CSV.zip',
#  '20200618.export.CSV.zip',
#  '20200617.export.CSV.zip',
#  '20200616.export.CSV.zip',
#  '20200615.export.CSV.zip',
#  '20200614.export.CSV.zip',
#  '20200613.export.CSV.zip',
#  '20200612.export.CSV.zip',
#  '20200611.export.CSV.zip',
#  '20200610.export.CSV.zip',
#  '20200609.export.CSV.zip',
#  '20200608.export.CSV.zip',
#  '20200607.export.CSV.zip',
#  '20200606.export.CSV.zip',
#  '20200605.export.CSV.zip',
#  '20200604.export.CSV.zip',
#  '20200603.export.CSV.zip',
#  '20200602.export.CSV.zip',
#  '20200601.export.CSV.zip',
#  '20200531.export.CSV.zip',
#  '20200530.export.CSV.zip',
#  '20200529.export.CSV.zip',
#  '20200528.export.CSV.zip',
#  '20200527.export.CSV.zip',
#  '20200526.export.CSV.zip',
#  '20200525.export.CSV.zip',
#  '20200524.export.CSV.zip',
#  '20200523.export.CSV.zip',
#  '20200522.export.CSV.zip',
#  '20200521.export.CSV.zip',
#  '20200520.export.CSV.zip',
#  '20200519.export.CSV.zip',
#  '20200518.export.CSV.zip',
#  '20200517.export.CSV.zip',
#  '20200516.export.CSV.zip',
#  '20200515.export.CSV.zip',
#  '20200514.export.CSV.zip',
#  '20200513.export.CSV.zip',
#  '20200512.export.CSV.zip',
#  '20200511.export.CSV.zip',
#  '20200510.export.CSV.zip',
#  '20200509.export.CSV.zip',
#  '20200508.export.CSV.zip',
#  '20200507.export.CSV.zip',
#  '20200506.export.CSV.zip',
#  '20200505.export.CSV.zip',
#  '20200504.export.CSV.zip',
#  '20200503.export.CSV.zip',
#  '20200502.export.CSV.zip',
#  '20200501.export.CSV.zip',
#  '20200430.export.CSV.zip',
#  '20200429.export.CSV.zip',
#  '20200428.export.CSV.zip',
#  '20200427.export.CSV.zip',
#  '20200426.export.CSV.zip',
#  '20200425.export.CSV.zip',
#  '20200424.export.CSV.zip',
#  '20200423.export.CSV.zip',
#  '20200422.export.CSV.zip',
#  '20200421.export.CSV.zip',
#  '20200420.export.CSV.zip',
#  '20200419.export.CSV.zip',
#  '20200418.export.CSV.zip',
#  '20200417.export.CSV.zip',
#  '20200416.export.CSV.zip',
#  '20200415.export.CSV.zip',
#  '20200414.export.CSV.zip',
#  '20200413.export.CSV.zip',
#  '20200412.export.CSV.zip',
#  '20200411.export.CSV.zip',
#  '20200410.export.CSV.zip',
#  '20200409.export.CSV.zip',
#  '20200408.export.CSV.zip',
#  '20200407.export.CSV.zip',
#  '20200406.export.CSV.zip',
#  '20200405.export.CSV.zip',
#  '20200404.export.CSV.zip',
#  '20200403.export.CSV.zip',
#  '20200402.export.CSV.zip',
#  '20200401.export.CSV.zip',
#  '20200331.export.CSV.zip',
#  '20200330.export.CSV.zip',
#  '20200329.export.CSV.zip',
#  '20200328.export.CSV.zip',
#  '20200327.export.CSV.zip',
#  '20200326.export.CSV.zip',
#  '20200325.export.CSV.zip',
#  '20200324.export.CSV.zip',
#  '20200323.export.CSV.zip',
#  '20200322.export.CSV.zip',
#  '20200321.export.CSV.zip',
#  '20200320.export.CSV.zip',
#  '20200319.export.CSV.zip',
#  '20200318.export.CSV.zip',
#  '20200317.export.CSV.zip',
#  '20200316.export.CSV.zip',
#  '20200315.export.CSV.zip',
#  '20200314.export.CSV.zip',
#  '20200313.export.CSV.zip',
#  '20200312.export.CSV.zip',
#  '20200311.export.CSV.zip',
#  '20200310.export.CSV.zip',
#  '20200309.export.CSV.zip',
#  '20200308.export.CSV.zip',
#  '20200307.export.CSV.zip',
#  '20200306.export.CSV.zip',
#  '20200305.export.CSV.zip',
#  '20200304.export.CSV.zip',
#  '20200303.export.CSV.zip',
#  '20200302.export.CSV.zip',
#  '20200301.export.CSV.zip',
#  '20200229.export.CSV.zip',
#  '20200228.export.CSV.zip',
#  '20200227.export.CSV.zip',
#  '20200226.export.CSV.zip',
#  '20200225.export.CSV.zip',
#  '20200224.export.CSV.zip',
#  '20200223.export.CSV.zip',
#  '20200222.export.CSV.zip',
#  '20200221.export.CSV.zip',
#  '20200220.export.CSV.zip',
#  '20200219.export.CSV.zip',
#  '20200218.export.CSV.zip',
#  '20200217.export.CSV.zip',
#  '20200216.export.CSV.zip',
#  '20200215.export.CSV.zip',
#  '20200214.export.CSV.zip',
#  '20200213.export.CSV.zip',
#  '20200212.export.CSV.zip',
#  '20200211.export.CSV.zip',
#  '20200210.export.CSV.zip',
#  '20200209.export.CSV.zip',
#  '20200208.export.CSV.zip',
#  '20200207.export.CSV.zip',
#  '20200206.export.CSV.zip',
#  '20200205.export.CSV.zip',
#  '20200204.export.CSV.zip',
#  '20200203.export.CSV.zip',
#  '20200202.export.CSV.zip',
#  '20200201.export.CSV.zip',
#  '20200131.export.CSV.zip',
#  '20200130.export.CSV.zip',
#  '20200129.export.CSV.zip',
#  '20200128.export.CSV.zip',
#  '20200127.export.CSV.zip',
#  '20200126.export.CSV.zip',
#  '20200125.export.CSV.zip',
#  '20200124.export.CSV.zip',
#  '20200123.export.CSV.zip',
#  '20200122.export.CSV.zip',
#  '20200121.export.CSV.zip',
#  '20200120.export.CSV.zip',
#  '20200119.export.CSV.zip',
#  '20200118.export.CSV.zip',
#  '20200117.export.CSV.zip',
#  '20200116.export.CSV.zip',
#  '20200115.export.CSV.zip',
#  '20200114.export.CSV.zip',
#  '20200113.export.CSV.zip',
#  '20200112.export.CSV.zip',
#  '20200111.export.CSV.zip',
#  '20200110.export.CSV.zip',
#  '20200109.export.CSV.zip',
#  '20200108.export.CSV.zip',
#  '20200107.export.CSV.zip',
#  '20200106.export.CSV.zip',
#  '20200105.export.CSV.zip',
#  '20200104.export.CSV.zip',
#  '20200103.export.CSV.zip',
#  '20200102.export.CSV.zip',
#  '20200101.export.CSV.zip',
#  '20191231.export.CSV.zip',
#  '20191230.export.CSV.zip',
#  '20191229.export.CSV.zip',
#  '20191228.export.CSV.zip',
#  '20191227.export.CSV.zip',
#  '20191226.export.CSV.zip',
#  '20191225.export.CSV.zip',
#  '20191224.export.CSV.zip',
#  '20191223.export.CSV.zip',
#  '20191222.export.CSV.zip',
#  '20191221.export.CSV.zip',
#  '20191220.export.CSV.zip',
#  '20191219.export.CSV.zip',
#  '20191218.export.CSV.zip',
#  '20191217.export.CSV.zip',
#  '20191216.export.CSV.zip',
#  '20191215.export.CSV.zip',
#  '20191214.export.CSV.zip',
#  '20191213.export.CSV.zip',
#  '20191212.export.CSV.zip',
#  '20191211.export.CSV.zip',
#  '20191210.export.CSV.zip',
#  '20191209.export.CSV.zip',
#  '20191208.export.CSV.zip',
#  '20191207.export.CSV.zip',
#  '20191206.export.CSV.zip',
#  '20191205.export.CSV.zip',
#  '20191204.export.CSV.zip',
#  '20191203.export.CSV.zip',
#  '20191202.export.CSV.zip',
#  '20191201.export.CSV.zip',
#  '20191130.export.CSV.zip',
#  '20191129.export.CSV.zip',
#  '20191128.export.CSV.zip',
#  '20191127.export.CSV.zip',
#  '20191126.export.CSV.zip',
#  '20191125.export.CSV.zip',
#  '20191124.export.CSV.zip',
#  '20191123.export.CSV.zip',
#  '20191122.export.CSV.zip',
#  '20191121.export.CSV.zip',
#  '20191120.export.CSV.zip',
#  '20191119.export.CSV.zip',
#  '20191118.export.CSV.zip',
#  '20191117.export.CSV.zip',
#  '20191116.export.CSV.zip',
#  '20191115.export.CSV.zip',
#  '20191114.export.CSV.zip',
#  '20191113.export.CSV.zip',
#  '20191112.export.CSV.zip',
#  '20191111.export.CSV.zip',
#  '20191110.export.CSV.zip',
#  '20191109.export.CSV.zip',
#  '20191108.export.CSV.zip',
#  '20191107.export.CSV.zip',
#  '20191106.export.CSV.zip',
#  '20191105.export.CSV.zip',
#  '20191104.export.CSV.zip',
#  '20191103.export.CSV.zip',
#  '20191102.export.CSV.zip',
#  '20191101.export.CSV.zip',
#  '20191031.export.CSV.zip',
#  '20191030.export.CSV.zip',
#  '20191029.export.CSV.zip',
#  '20191028.export.CSV.zip',
#  '20191027.export.CSV.zip',
#  '20191026.export.CSV.zip',
#  '20191025.export.CSV.zip',
#  '20191024.export.CSV.zip',
#  '20191023.export.CSV.zip',
#  '20191022.export.CSV.zip',
#  '20191021.export.CSV.zip',
#  '20191020.export.CSV.zip',
#  '20191019.export.CSV.zip',
#  '20191018.export.CSV.zip',
#  '20191017.export.CSV.zip',
#  '20191016.export.CSV.zip',
#  '20191015.export.CSV.zip',
#  '20191014.export.CSV.zip',
#  '20191013.export.CSV.zip',
#  '20191012.export.CSV.zip',
#  '20191011.export.CSV.zip',
#  '20191010.export.CSV.zip',
#  '20191009.export.CSV.zip',
#  '20191008.export.CSV.zip',
#  '20191007.export.CSV.zip',
#  '20191006.export.CSV.zip',
#  '20191005.export.CSV.zip',
#  '20191004.export.CSV.zip',
#  '20191003.export.CSV.zip',
#  '20191002.export.CSV.zip',
#  '20191001.export.CSV.zip',
#  '20190930.export.CSV.zip',
#  '20190929.export.CSV.zip',
#  '20190928.export.CSV.zip',
#  '20190927.export.CSV.zip',
#  '20190926.export.CSV.zip',
#  '20190925.export.CSV.zip',
#  '20190924.export.CSV.zip',
#  '20190923.export.CSV.zip',
#  '20190922.export.CSV.zip',
#  '20190921.export.CSV.zip',
#  '20190920.export.CSV.zip',
#  '20190919.export.CSV.zip',
#  '20190918.export.CSV.zip',
#  '20190917.export.CSV.zip',
#  '20190916.export.CSV.zip',
#  '20190915.export.CSV.zip',
#  '20190914.export.CSV.zip',
#  '20190913.export.CSV.zip',
#  '20190912.export.CSV.zip',
#  '20190911.export.CSV.zip',
#  '20190910.export.CSV.zip',
#  '20190909.export.CSV.zip',
#  '20190908.export.CSV.zip',
#  '20190907.export.CSV.zip',
#  '20190906.export.CSV.zip',
#  '20190905.export.CSV.zip',
#  '20190904.export.CSV.zip',
#  '20190903.export.CSV.zip',
#  '20190902.export.CSV.zip',
#  '20190901.export.CSV.zip',
#  '20190831.export.CSV.zip',
#  '20190830.export.CSV.zip',
#  '20190829.export.CSV.zip',
#  '20190828.export.CSV.zip',
#  '20190827.export.CSV.zip',
#  '20190826.export.CSV.zip',
#  '20190825.export.CSV.zip',
#  '20190824.export.CSV.zip',
#  '20190823.export.CSV.zip',
#  '20190822.export.CSV.zip',
#  '20190821.export.CSV.zip',
#  '20190820.export.CSV.zip',
#  '20190819.export.CSV.zip',
#  '20190818.export.CSV.zip',
#  '20190817.export.CSV.zip',
#  '20190816.export.CSV.zip',
#  '20190815.export.CSV.zip',
#  '20190814.export.CSV.zip',
#  '20190813.export.CSV.zip',
#  '20190812.export.CSV.zip',
#  '20190811.export.CSV.zip',
#  '20190810.export.CSV.zip',
#  '20190809.export.CSV.zip',
#  '20190808.export.CSV.zip',
#  '20190807.export.CSV.zip',
#  '20190806.export.CSV.zip',
#  '20190805.export.CSV.zip',
#  '20190804.export.CSV.zip',
#  '20190803.export.CSV.zip',
#  '20190802.export.CSV.zip',
#  '20190801.export.CSV.zip',
#  '20190731.export.CSV.zip',
#  '20190730.export.CSV.zip',
#  '20190729.export.CSV.zip',
#  '20190728.export.CSV.zip',
#  '20190727.export.CSV.zip',
#  '20190726.export.CSV.zip',
#  '20190725.export.CSV.zip',
#  '20190724.export.CSV.zip',
#  '20190723.export.CSV.zip',
#  '20190722.export.CSV.zip',
#  '20190721.export.CSV.zip',
#  '20190720.export.CSV.zip',
#  '20190719.export.CSV.zip',
#  '20190718.export.CSV.zip',
#  '20190717.export.CSV.zip',
#  '20190716.export.CSV.zip',
#  '20190715.export.CSV.zip',
#  '20190714.export.CSV.zip',
#  '20190713.export.CSV.zip',
#  '20190712.export.CSV.zip',
#  '20190711.export.CSV.zip',
#  '20190710.export.CSV.zip',
#  '20190709.export.CSV.zip',
#  '20190708.export.CSV.zip',
#  '20190707.export.CSV.zip',
#  '20190706.export.CSV.zip',
#  '20190705.export.CSV.zip',
#  '20190704.export.CSV.zip',
#  '20190703.export.CSV.zip',
#  '20190702.export.CSV.zip',
#  '20190701.export.CSV.zip',
#  '20190630.export.CSV.zip',
#  '20190629.export.CSV.zip',
#  '20190628.export.CSV.zip',
#  '20190627.export.CSV.zip',
#  '20190626.export.CSV.zip',
#  '20190625.export.CSV.zip',
#  '20190624.export.CSV.zip',
#  '20190623.export.CSV.zip',
#  '20190622.export.CSV.zip',
#  '20190621.export.CSV.zip',
#  '20190620.export.CSV.zip',
#  '20190619.export.CSV.zip',
#  '20190618.export.CSV.zip',
#  '20190617.export.CSV.zip',
#  '20190616.export.CSV.zip',
#  '20190615.export.CSV.zip',
#  '20190614.export.CSV.zip',
#  '20190613.export.CSV.zip',
#  '20190612.export.CSV.zip',
#  '20190611.export.CSV.zip',
#  '20190610.export.CSV.zip',
#  '20190609.export.CSV.zip',
#  '20190608.export.CSV.zip',
#  '20190607.export.CSV.zip',
#  '20190606.export.CSV.zip',
#  '20190605.export.CSV.zip',
#  '20190604.export.CSV.zip',
#  '20190603.export.CSV.zip',
#  '20190602.export.CSV.zip',
#  '20190601.export.CSV.zip',
#  '20190531.export.CSV.zip',
#  '20190530.export.CSV.zip',
#  '20190529.export.CSV.zip',
#  '20190528.export.CSV.zip',
#  '20190527.export.CSV.zip',
#  '20190526.export.CSV.zip',
#  '20190525.export.CSV.zip',
#  '20190524.export.CSV.zip',
#  '20190523.export.CSV.zip',
#  '20190522.export.CSV.zip',
#  '20190521.export.CSV.zip',
#  '20190520.export.CSV.zip',
#  '20190519.export.CSV.zip',
#  '20190518.export.CSV.zip',
#  '20190517.export.CSV.zip',
#  '20190516.export.CSV.zip',
#  '20190515.export.CSV.zip',
#  '20190514.export.CSV.zip',
#  '20190513.export.CSV.zip',
#  '20190512.export.CSV.zip',
#  '20190511.export.CSV.zip',
#  '20190510.export.CSV.zip',
#  '20190509.export.CSV.zip',
#  '20190508.export.CSV.zip',
#  '20190507.export.CSV.zip',
#  '20190506.export.CSV.zip',
#  '20190505.export.CSV.zip',
#  '20190504.export.CSV.zip',
#  '20190503.export.CSV.zip',
#  '20190502.export.CSV.zip',
#  '20190501.export.CSV.zip',
#  '20190430.export.CSV.zip',
#  '20190429.export.CSV.zip',
#  '20190428.export.CSV.zip',
#  '20190427.export.CSV.zip',
#  '20190426.export.CSV.zip',
#  '20190425.export.CSV.zip',
#  '20190424.export.CSV.zip',
#  '20190423.export.CSV.zip',
#  '20190422.export.CSV.zip',
#  '20190421.export.CSV.zip',
#  '20190420.export.CSV.zip',
#  '20190419.export.CSV.zip',
#  '20190418.export.CSV.zip',
#  '20190417.export.CSV.zip',
#  '20190416.export.CSV.zip',
#  '20190415.export.CSV.zip',
#  '20190414.export.CSV.zip',
#  '20190413.export.CSV.zip',
#  '20190412.export.CSV.zip',
#  '20190411.export.CSV.zip',
#  '20190410.export.CSV.zip',
#  '20190409.export.CSV.zip',
#  '20190408.export.CSV.zip',
#  '20190407.export.CSV.zip',
#  '20190406.export.CSV.zip',
#  '20190405.export.CSV.zip',
#  '20190404.export.CSV.zip',
#  '20190403.export.CSV.zip',
#  '20190402.export.CSV.zip',
#  '20190401.export.CSV.zip',
#  '20190331.export.CSV.zip',
#  '20190330.export.CSV.zip',
#  '20190329.export.CSV.zip',
#  '20190328.export.CSV.zip',
#  '20190327.export.CSV.zip',
#  '20190326.export.CSV.zip',
#  '20190325.export.CSV.zip',
#  '20190324.export.CSV.zip',
#  '20190323.export.CSV.zip',
#  '20190322.export.CSV.zip',
#  '20190321.export.CSV.zip',
#  '20190320.export.CSV.zip',
#  '20190319.export.CSV.zip',
#  '20190318.export.CSV.zip',
#  '20190317.export.CSV.zip',
#  '20190316.export.CSV.zip',
#  '20190315.export.CSV.zip',
#  '20190314.export.CSV.zip',
#  '20190313.export.CSV.zip',
#  '20190312.export.CSV.zip',
#  '20190311.export.CSV.zip',
#  '20190310.export.CSV.zip',
#  '20190309.export.CSV.zip',
#  '20190308.export.CSV.zip',
#  '20190307.export.CSV.zip',
#  '20190306.export.CSV.zip',
#  '20190305.export.CSV.zip',
#  '20190304.export.CSV.zip',
#  '20190303.export.CSV.zip',
#  '20190302.export.CSV.zip',
#  '20190301.export.CSV.zip',
#  '20190228.export.CSV.zip',
#  '20190227.export.CSV.zip',
#  '20190226.export.CSV.zip',
#  '20190225.export.CSV.zip',
#  '20190224.export.CSV.zip',
#  '20190223.export.CSV.zip',
#  '20190222.export.CSV.zip',
#  '20190221.export.CSV.zip',
#  '20190220.export.CSV.zip',
#  '20190219.export.CSV.zip',
#  '20190218.export.CSV.zip',
#  '20190217.export.CSV.zip',
#  '20190216.export.CSV.zip',
#  '20190215.export.CSV.zip',
#  '20190214.export.CSV.zip',
#  '20190213.export.CSV.zip',
#  '20190212.export.CSV.zip',
#  '20190211.export.CSV.zip',
#  '20190210.export.CSV.zip',
#  '20190209.export.CSV.zip',
#  '20190208.export.CSV.zip',
#  '20190207.export.CSV.zip',
#  '20190206.export.CSV.zip',
#  '20190205.export.CSV.zip',
#  '20190204.export.CSV.zip',
#  '20190203.export.CSV.zip',
#  '20190202.export.CSV.zip',
#  '20190201.export.CSV.zip',
#  '20190131.export.CSV.zip',
#  '20190130.export.CSV.zip',
#  '20190129.export.CSV.zip',
#  '20190128.export.CSV.zip',
#  '20190127.export.CSV.zip',
#  '20190126.export.CSV.zip',
#  '20190125.export.CSV.zip',
#  '20190124.export.CSV.zip',
#  '20190123.export.CSV.zip',
#  '20190122.export.CSV.zip',
#  '20190121.export.CSV.zip',
#  '20190120.export.CSV.zip',
#  '20190119.export.CSV.zip',
#  '20190118.export.CSV.zip',
#  '20190117.export.CSV.zip',
#  '20190116.export.CSV.zip',
#  '20190115.export.CSV.zip',
#  '20190114.export.CSV.zip',
#  '20190113.export.CSV.zip',
#  '20190112.export.CSV.zip',
#  '20190111.export.CSV.zip',
#  '20190110.export.CSV.zip',
#  '20190109.export.CSV.zip',
#  '20190108.export.CSV.zip',
#  '20190107.export.CSV.zip',
#  '20190106.export.CSV.zip',
#  '20190105.export.CSV.zip',
#  '20190104.export.CSV.zip',
#  '20190103.export.CSV.zip',
#  '20190102.export.CSV.zip',
#  '20190101.export.CSV.zip',
#  '20181231.export.CSV.zip',
#  '20181230.export.CSV.zip',
#  '20181229.export.CSV.zip',
#  '20181228.export.CSV.zip',
#  '20181227.export.CSV.zip',
#  '20181226.export.CSV.zip',
#  '20181225.export.CSV.zip',
#  '20181224.export.CSV.zip',
#  '20181223.export.CSV.zip',
#  '20181222.export.CSV.zip',
#  '20181221.export.CSV.zip',
#  '20181220.export.CSV.zip',
#  '20181219.export.CSV.zip',
#  '20181218.export.CSV.zip',
#  '20181217.export.CSV.zip',
#  '20181216.export.CSV.zip',
#  '20181215.export.CSV.zip',
#  '20181214.export.CSV.zip',
#  '20181213.export.CSV.zip',
#  '20181212.export.CSV.zip',
#  '20181211.export.CSV.zip',
#  '20181210.export.CSV.zip',
#  '20181209.export.CSV.zip',
#  '20181208.export.CSV.zip',
#  '20181207.export.CSV.zip',
#  '20181206.export.CSV.zip',
#  '20181205.export.CSV.zip',
#  '20181204.export.CSV.zip',
#  '20181203.export.CSV.zip',
#  '20181202.export.CSV.zip',
#  '20181201.export.CSV.zip',
#  '20181130.export.CSV.zip',
#  '20181129.export.CSV.zip',
#  '20181128.export.CSV.zip',
#  '20181127.export.CSV.zip',
#  '20181126.export.CSV.zip',
#  '20181125.export.CSV.zip',
#  '20181124.export.CSV.zip',
#  '20181123.export.CSV.zip',
#  '20181122.export.CSV.zip',
#  '20181121.export.CSV.zip',
#  '20181120.export.CSV.zip',
#  '20181119.export.CSV.zip',
#  '20181118.export.CSV.zip',
#  '20181117.export.CSV.zip',
#  '20181116.export.CSV.zip',
#  '20181115.export.CSV.zip',
#  '20181114.export.CSV.zip',
#  '20181113.export.CSV.zip',
#  '20181112.export.CSV.zip',
#  '20181111.export.CSV.zip',
#  '20181110.export.CSV.zip',
#  '20181109.export.CSV.zip',
#  '20181108.export.CSV.zip',
#  '20181107.export.CSV.zip',
#  '20181106.export.CSV.zip',
#  '20181105.export.CSV.zip',
#  '20181104.export.CSV.zip',
#  '20181103.export.CSV.zip',
#  '20181102.export.CSV.zip',
#  '20181101.export.CSV.zip',
#  '20181031.export.CSV.zip',
#  '20181030.export.CSV.zip',
#  '20181029.export.CSV.zip',
#  '20181028.export.CSV.zip',
#  '20181027.export.CSV.zip',
#  '20181026.export.CSV.zip',
#  '20181025.export.CSV.zip',
#  '20181024.export.CSV.zip',
#  '20181023.export.CSV.zip',
#  '20181022.export.CSV.zip',
#  '20181021.export.CSV.zip',
#  '20181020.export.CSV.zip',
#  '20181019.export.CSV.zip',
#  '20181018.export.CSV.zip',
#  '20181017.export.CSV.zip',
#  '20181016.export.CSV.zip',
#  '20181015.export.CSV.zip',
#  '20181014.export.CSV.zip',
#  '20181013.export.CSV.zip',
#  '20181012.export.CSV.zip',
#  '20181011.export.CSV.zip',
#  '20181010.export.CSV.zip',
#  '20181009.export.CSV.zip',
#  '20181008.export.CSV.zip',
#  '20181007.export.CSV.zip',
#  '20181006.export.CSV.zip',
#  '20181005.export.CSV.zip',
#  '20181004.export.CSV.zip',
#  '20181003.export.CSV.zip',
#  '20181002.export.CSV.zip',
#  '20181001.export.CSV.zip',
#  '20180930.export.CSV.zip',
#  '20180929.export.CSV.zip',
#  '20180928.export.CSV.zip',
#  '20180927.export.CSV.zip',
#  '20180926.export.CSV.zip',
#  '20180925.export.CSV.zip',
#  '20180924.export.CSV.zip',
#  '20180923.export.CSV.zip',
#  '20180922.export.CSV.zip',
#  '20180921.export.CSV.zip',
#  '20180920.export.CSV.zip',
#  '20180919.export.CSV.zip',
#  '20180918.export.CSV.zip',
#  '20180917.export.CSV.zip',
#  '20180916.export.CSV.zip',
#  '20180915.export.CSV.zip',
#  '20180914.export.CSV.zip',
#  '20180913.export.CSV.zip',
#  '20180912.export.CSV.zip',
#  '20180911.export.CSV.zip',
#  '20180910.export.CSV.zip',
#  '20180909.export.CSV.zip',
#  '20180908.export.CSV.zip',
#  '20180907.export.CSV.zip',
#  '20180906.export.CSV.zip',
#  '20180905.export.CSV.zip',
#  '20180904.export.CSV.zip',
#  '20180903.export.CSV.zip',
#  '20180902.export.CSV.zip',
#  '20180901.export.CSV.zip',
#  '20180831.export.CSV.zip',
#  '20180830.export.CSV.zip',
#  '20180829.export.CSV.zip',
#  '20180828.export.CSV.zip',
#  '20180827.export.CSV.zip',
#  '20180826.export.CSV.zip',
#  '20180825.export.CSV.zip',
#  '20180824.export.CSV.zip',
#  '20180823.export.CSV.zip',
#  '20180822.export.CSV.zip',
#  '20180821.export.CSV.zip',
#  '20180820.export.CSV.zip',
#  '20180819.export.CSV.zip',
#  '20180818.export.CSV.zip',
#  '20180817.export.CSV.zip',
#  '20180816.export.CSV.zip',
#  '20180815.export.CSV.zip',
#  '20180814.export.CSV.zip',
#  '20180813.export.CSV.zip',
#  '20180812.export.CSV.zip',
#  '20180811.export.CSV.zip',
#  '20180810.export.CSV.zip',
#  '20180809.export.CSV.zip',
#  '20180808.export.CSV.zip',
#  '20180807.export.CSV.zip',
#  '20180806.export.CSV.zip',
#  '20180805.export.CSV.zip',
#  '20180804.export.CSV.zip',
#  '20180803.export.CSV.zip',
#  '20180802.export.CSV.zip',
#  '20180801.export.CSV.zip',
#  '20180731.export.CSV.zip',
#  '20180730.export.CSV.zip',
#  '20180729.export.CSV.zip',
#  '20180728.export.CSV.zip',
#  '20180727.export.CSV.zip',
#  '20180726.export.CSV.zip',
#  '20180725.export.CSV.zip',
#  '20180724.export.CSV.zip',
#  '20180723.export.CSV.zip',
#  '20180722.export.CSV.zip',
#  '20180721.export.CSV.zip',
#  '20180720.export.CSV.zip',
#  '20180719.export.CSV.zip',
#  '20180718.export.CSV.zip',
#  '20180717.export.CSV.zip',
#  '20180716.export.CSV.zip',
#  '20180715.export.CSV.zip',
#  '20180714.export.CSV.zip',
#  '20180713.export.CSV.zip',
#  '20180712.export.CSV.zip',
#  '20180711.export.CSV.zip',
#  '20180710.export.CSV.zip',
#  '20180709.export.CSV.zip',
#  '20180708.export.CSV.zip',
#  '20180707.export.CSV.zip',
#  '20180706.export.CSV.zip',
#  '20180705.export.CSV.zip',
#  '20180704.export.CSV.zip',
#  '20180703.export.CSV.zip',
#  '20180702.export.CSV.zip',
#  '20180701.export.CSV.zip',
#  '20180630.export.CSV.zip',
#  '20180629.export.CSV.zip',
#  '20180628.export.CSV.zip',
#  '20180627.export.CSV.zip',
#  '20180626.export.CSV.zip',
#  '20180625.export.CSV.zip',
#  '20180624.export.CSV.zip',
#  '20180623.export.CSV.zip',
#  '20180622.export.CSV.zip',
#  '20180621.export.CSV.zip',
#  '20180620.export.CSV.zip',
#  '20180619.export.CSV.zip',
#  '20180618.export.CSV.zip',
#  '20180617.export.CSV.zip',
#  '20180616.export.CSV.zip',
#  '20180615.export.CSV.zip',
#  '20180614.export.CSV.zip',
#  '20180613.export.CSV.zip',
#  '20180612.export.CSV.zip',
#  '20180611.export.CSV.zip',
#  '20180610.export.CSV.zip',
#  '20180609.export.CSV.zip',
#  '20180608.export.CSV.zip',
#  '20180607.export.CSV.zip',
#  '20180606.export.CSV.zip',
#  '20180605.export.CSV.zip',
#  '20180604.export.CSV.zip',
#  '20180603.export.CSV.zip',
#  '20180602.export.CSV.zip',
#  '20180601.export.CSV.zip',
#  '20180531.export.CSV.zip',
#  '20180530.export.CSV.zip',
#  '20180529.export.CSV.zip',
#  '20180528.export.CSV.zip',
#  '20180527.export.CSV.zip',
#  '20180526.export.CSV.zip',
#  '20180525.export.CSV.zip',
#  '20180524.export.CSV.zip',
#  '20180523.export.CSV.zip',
#  '20180522.export.CSV.zip',
#  '20180521.export.CSV.zip',
#  '20180520.export.CSV.zip',
#  '20180519.export.CSV.zip',
#  '20180518.export.CSV.zip',
#  '20180517.export.CSV.zip',
#  '20180516.export.CSV.zip',
#  '20180515.export.CSV.zip',
#  '20180514.export.CSV.zip',
#  '20180513.export.CSV.zip',
#  '20180512.export.CSV.zip',
#  '20180511.export.CSV.zip',
#  '20180510.export.CSV.zip',
#  '20180509.export.CSV.zip',
#  '20180508.export.CSV.zip',
#  '20180507.export.CSV.zip',
#  '20180506.export.CSV.zip',
#  '20180505.export.CSV.zip',
#  '20180504.export.CSV.zip',
#  '20180503.export.CSV.zip',
#  '20180502.export.CSV.zip',
#  '20180501.export.CSV.zip',
#  '20180430.export.CSV.zip',
#  '20180429.export.CSV.zip',
#  '20180428.export.CSV.zip',
#  '20180427.export.CSV.zip',
#  '20180426.export.CSV.zip',
#  '20180425.export.CSV.zip',
#  '20180424.export.CSV.zip',
#  '20180423.export.CSV.zip',
#  '20180422.export.CSV.zip',
#  '20180421.export.CSV.zip',
#  '20180420.export.CSV.zip',
#  '20180419.export.CSV.zip',
#  '20180418.export.CSV.zip',
#  '20180417.export.CSV.zip',
#  '20180416.export.CSV.zip',
#  '20180415.export.CSV.zip',
#  '20180414.export.CSV.zip',
#  '20180413.export.CSV.zip',
#  '20180412.export.CSV.zip',
#  '20180411.export.CSV.zip',
#  '20180410.export.CSV.zip',
#  '20180409.export.CSV.zip',
#  '20180408.export.CSV.zip',
#  '20180407.export.CSV.zip',
#  '20180406.export.CSV.zip',
#  '20180405.export.CSV.zip',
#  '20180404.export.CSV.zip',
#  '20180403.export.CSV.zip',
#  '20180402.export.CSV.zip',
#  '20180401.export.CSV.zip',
#  '20180331.export.CSV.zip',
#  '20180330.export.CSV.zip',
#  '20180329.export.CSV.zip',
#  '20180328.export.CSV.zip',
#  '20180327.export.CSV.zip',
#  '20180326.export.CSV.zip',
#  '20180325.export.CSV.zip',
#  '20180324.export.CSV.zip',
#  '20180323.export.CSV.zip',
#  '20180322.export.CSV.zip',
#  '20180321.export.CSV.zip',
#  '20180320.export.CSV.zip',
#  '20180319.export.CSV.zip',
#  '20180318.export.CSV.zip',
#  '20180317.export.CSV.zip',
#  '20180316.export.CSV.zip',
#  '20180315.export.CSV.zip',
#  '20180314.export.CSV.zip',
#  '20180313.export.CSV.zip',
#  '20180312.export.CSV.zip',
#  '20180311.export.CSV.zip',
#  '20180310.export.CSV.zip',
#  '20180309.export.CSV.zip',
#  '20180308.export.CSV.zip',
#  '20180307.export.CSV.zip',
#  '20180306.export.CSV.zip',
#  '20180305.export.CSV.zip',
#  '20180304.export.CSV.zip',
#  '20180303.export.CSV.zip',
#  '20180302.export.CSV.zip',
#  '20180301.export.CSV.zip',
#  '20180228.export.CSV.zip',
#  '20180227.export.CSV.zip',
#  '20180226.export.CSV.zip',
#  '20180225.export.CSV.zip',
#  '20180224.export.CSV.zip',
#  '20180223.export.CSV.zip',
#  '20180222.export.CSV.zip',
#  '20180221.export.CSV.zip',
#  '20180220.export.CSV.zip',
#  '20180219.export.CSV.zip',
#  '20180218.export.CSV.zip',
#  '20180217.export.CSV.zip',
#  '20180216.export.CSV.zip',
#  '20180215.export.CSV.zip',
#  '20180214.export.CSV.zip',
#  '20180213.export.CSV.zip',
#  '20180212.export.CSV.zip',
#  '20180211.export.CSV.zip',
#  '20180210.export.CSV.zip',
#  '20180209.export.CSV.zip',
#  '20180208.export.CSV.zip',
#  '20180207.export.CSV.zip',
#  '20180206.export.CSV.zip',
#  '20180205.export.CSV.zip',
#  '20180204.export.CSV.zip',
#  '20180203.export.CSV.zip',
#  '20180202.export.CSV.zip',
#  '20180201.export.CSV.zip',
#  '20180131.export.CSV.zip',
#  '20180130.export.CSV.zip',
#  '20180129.export.CSV.zip',
#  '20180128.export.CSV.zip',
#  '20180127.export.CSV.zip',
#  '20180126.export.CSV.zip',
#  '20180125.export.CSV.zip',
#  '20180124.export.CSV.zip',
#  '20180123.export.CSV.zip',
#  '20180122.export.CSV.zip',
#  '20180121.export.CSV.zip',
#  '20180120.export.CSV.zip',
#  '20180119.export.CSV.zip',
#  '20180118.export.CSV.zip',
#  '20180117.export.CSV.zip',
#  '20180116.export.CSV.zip',
#  '20180115.export.CSV.zip',
#  '20180114.export.CSV.zip',
#  '20180113.export.CSV.zip',
#  '20180112.export.CSV.zip',
#  '20180111.export.CSV.zip',
#  '20180110.export.CSV.zip',
#  '20180109.export.CSV.zip',
#  ...]

# %%
#Counters to help assess how many files are coming and going out
infilecounter = 0
outfilecounter = 0

# %% [markdown]
# ### Uses GDELT Index file list to download GDELT data for that day for that country

# %%
import os.path #To help navigate the file directories
import urllib #To request from GDELT
import zipfile #TO unzip the files we downlaod
import glob #To go through multiple files in a directory
import operator 

local_path = './results/' # Will save to empy results folder to help keep file clean

fips_country_code = 'SF'  # Changed country code to South Africa

#Adjust list number to get days wanted 
for compressed_file in file_list[:9]: # To get the past 9 days
    print(compressed_file,)
    
    # if we dont have the compressed file stored locally, go get it. Keep trying if necessary.
    while not os.path.isfile(local_path+compressed_file): 
        print('downloading,'),
        urllib.request.urlretrieve(url=gdelt_base_url+compressed_file, 
                           filename=local_path+compressed_file)
        
    # extract the contents of the compressed file to a temporary directory    
    print('extracting,'),
    z = zipfile.ZipFile(file=local_path+compressed_file, mode='r')    
    z.extractall(path=local_path+'tmp/')
    
    # parse each of the csv files in the working directory, 
    print('parsing,'),
    for infile_name in glob.glob(local_path+'tmp/*'):
        outfile_name = local_path+fips_country_code+'%04i.tsv'%outfilecounter
        
        # open the infile and outfile
        with open(infile_name, mode='r', encoding="ISO-8859-1") as infile, open(outfile_name, mode='w') as outfile:
            for line in infile:
                # extract lines with our interest country code
                if fips_country_code in operator.itemgetter(51, 37, 44)(line.split('\t')):    
                    outfile.write(line)
            outfilecounter +=1
            
        # delete the temporary file
        os.remove(infile_name)
    infilecounter +=1
    print('done', infilecounter)
# Out:
# 20201004.export.CSV.zip
# extracting,
# parsing,
# done 1
# 20201003.export.CSV.zip
# extracting,
# parsing,
# done 2
# 20201002.export.CSV.zip
# extracting,
# parsing,
# done 3
# 20201001.export.CSV.zip
# extracting,
# parsing,
# done 4
# 20200930.export.CSV.zip
# extracting,
# parsing,
# done 5
# 20200929.export.CSV.zip
# extracting,
# parsing,
# done 6
# 20200928.export.CSV.zip
# extracting,
# parsing,
# done 7
# 20200927.export.CSV.zip
# extracting,
# parsing,
# done 8
# 20200926.export.CSV.zip
# extracting,
# parsing,
# done 9

# %% [markdown]
# # PART II:  PARSE DATA AGAIN
#
# ### Read in the data

# %%
import pandas as pd

# Get the GDELT field names from a helper file
colnames = pd.read_csv('CSV.header.fieldids.csv')['Field Name']


# Build DataFrames from each of the intermediary files
files = glob.glob(local_path+fips_country_code+'*')
DFlist = []
for active_file in files:
    print(active_file)
    DFlist.append(pd.read_csv(active_file, sep='\t', header=None, dtype=str,
                              names=colnames, index_col=['GLOBALEVENTID'], encoding='iso-8859-1'))

# Merge the file-based dataframes and save a pickle
DF = pd.concat(DFlist)
DF.to_pickle(local_path+'backup'+fips_country_code+'.pickle')    
    
# once everythin is safely stored away, remove the temporary files
for active_file in files:
    os.remove(active_file)
# Out:
# ./results/SF0000.tsv
# ./results/SF0001.tsv
# ./results/SF0002.tsv
# ./results/SF0003.tsv
# ./results/SF0004.tsv
# ./results/SF0005.tsv
# ./results/SF0006.tsv
# ./results/SF0007.tsv
# ./results/SF0008.tsv

# %%
import pickle

SF_Data = pd.read_pickle(r"./results/backupSF.pickle") # CHanged from Niger_Data to SF_Data

# %% [markdown]
# ### See top 5 lines of data

# %%
SF_Data.head()
# Out:
#                 SQLDATE MonthYear  Year FractionDate Actor1Code   Actor1Name  \
# GLOBALEVENTID
# 950095801      20201004    202010  2020    2020.7507        AFR       AFRICA
# 950096906      20201004    202010  2020    2020.7507        MED  LOCAL MEDIA
# 950097736      20201004    202010  2020    2020.7507        NaN          NaN
# 950097860      20201004    202010  2020    2020.7507        AFR       AFRICA
# 950097861      20201004    202010  2020    2020.7507        AFR       AFRICA
#
#               Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# GLOBALEVENTID
# 950095801                   AFR                  NaN              NaN
# 950096906                   NaN                  NaN              NaN
# 950097736                   NaN                  NaN              NaN
# 950097860                   AFR                  NaN              NaN
# 950097861                   AFR                  NaN              NaN
#
#               Actor1Religion1Code  ... Actor2Geo_FeatureID ActionGeo_Type  \
# GLOBALEVENTID                      ...
# 950095801                     NaN  ...              204226              5
# 950096906                     NaN  ...                 NaN              5
# 950097736                     NaN  ...            -1224926              4
# 950097860                     NaN  ...                 NaN              4
# 950097861                     NaN  ...                 NaN              4
#
#                                   ActionGeo_FullName ActionGeo_CountryCode  \
# GLOBALEVENTID
# 950095801             Gauteng, Gauteng, South Africa                    SF
# 950096906             Gauteng, Gauteng, South Africa                    SF
# 950097736        Durban, KwaZulu-Natal, South Africa                    SF
# 950097860      Cape Town, Western Cape, South Africa                    SF
# 950097861        Johannesburg, Gauteng, South Africa                    SF
#
#               ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long  \
# GLOBALEVENTID
# 950095801                   SF06      -26.0833          28.25
# 950096906                   SF06      -26.0833          28.25
# 950097736                   SF02        -29.85        31.0167
# 950097860                   SF11      -33.9167        18.4167
# 950097861                   SF06         -26.2        28.0833
#
#               ActionGeo_FeatureID DATEADDED  \
# GLOBALEVENTID
# 950095801                  204226  20201004
# 950096906                  204226  20201004
# 950097736                -1224926  20201004
# 950097860                -1217214  20201004
# 950097861                -1240261  20201004
#
#                                                        SOURCEURL
# GLOBALEVENTID
# 950095801      https://lowvelder.co.za/lnn/1144782/covid-19-a...
# 950096906      https://lowvelder.co.za/lnn/1144782/covid-19-a...
# 950097736      https://www.enca.com/news/emirates-cancels-fli...
# 950097860      https://www.enca.com/news/police-expect-more-a...
# 950097861      https://mynorthwest.com/2206366/south-african-...
#
# [5 rows x 57 columns]

# %% [markdown]
# ### Helper Function  to turn codebooks  into look up tables

# %%
def ref_dict(df):
    cols = list(df)
    ref_dict = {}
    for row in df.iterrows(): 
        ref_dict[row[1][cols[0]]] = row[1][cols[1]]
    
    return ref_dict

# %% [markdown]
# ### Convert each codebook and store in object

# %%
#Read in event codes
eventCodes = ref_dict(pd.read_csv("./Ref Codes/CAMEO.eventcodes.txt", sep='\t'))
#Read in Goldsteinscale
goldScale = ref_dict(pd.read_csv("./Ref Codes/CAMEO.goldsteinscale.txt", sep='\t'))
#Read in ethnic groups
ethnicCodes =ref_dict(pd.read_csv("./Ref Codes/CAMEO.ethnic.txt", sep='\t'))
#Read in known Groups
knownGroups = ref_dict(pd.read_csv("./Ref Codes/CAMEO.knowngroup.txt", sep='\t'))
#Read in relgion
religionCodes = ref_dict(pd.read_csv("./Ref Codes/CAMEO.religion.txt", sep='\t'))
#Read in type
typeCodes = ref_dict(pd.read_csv("./Ref Codes/CAMEO.type.txt", sep='\t'))

print(typeCodes)
# Out:
# {'COP': 'Police forces', 'GOV': 'Government', 'INS': 'Insurgents', 'JUD': 'Judiciary', 'MIL': 'Military', 'OPP': 'Political Opposition', 'REB': 'Rebels', 'SEP': 'Separatist Rebels', 'SPY': 'State Intelligence', 'UAF': 'Unaligned Armed Forces', 'AGR': 'Agriculture', 'BUS': 'Business', 'CRM': 'Criminal', 'CVL': 'Civilian', 'DEV': 'Development', 'EDU': 'Education', 'ELI': 'Elites', 'ENV': 'Environmental', 'HLH': 'Health', 'HRI': 'Human Rights', 'LAB': 'Labor', 'LEG': 'Legislature', 'MED': 'Media', 'REF': 'Refugees', 'MOD': 'Moderate', 'RAD': 'Radical', 'AMN': 'Amnesty International', 'IRC': 'Red Cross', 'GRP': 'Greenpeace', 'UNO': 'United Nations', 'PKO': 'Peacekeepers', 'UIS': 'Unidentified State Actor', 'IGO': 'Inter-Governmental Organization', 'IMG': 'International Militarized Group', 'INT': 'International/Transnational Generic', 'MNC': 'Multinational Corporation', 'NGM': 'Non-Governmental Movement', 'NGO': 'Non-Governmental Organization', 'SET': 'Settler'}

# %%
# Turn colnames into list for ref

cross_ref = list(colnames)
#cross_ref

# %%
# Create look up table to get values instead of numbers

look_up_code = {"eventCodes": [26,27,28], "goldScale":[30], "ethnicCodes":[9,19], "knownGroups":[8,18], 
                "religionCodes":[10,11,20,21] , "typeCodes":[12,13,14,22,23,24]}

# %%
'''
Helper function to user can reorient data based on interest from codes

data: SF_Data - pandas dataframe
ref: key value from look_look_code - string
codebook: reference 
'''

import math

def search_dict(data,ref, codebook):
    res = {}
    look_up = look_up_code[ref]
    col_names = []
    for i in look_up: 
        col_names.append(cross_ref[i])
    
    #print(col_names)
    for col in col_names: 
        for row in data.iterrows():
            if isinstance(row[1][col],float):
                #print (type(row[1][col]), col)
                pass
            else: 
                #print (col)
                var = codebook[row[1][col]].upper()
                #print (var, row[1][col])
                if var in res.keys(): 
                    #print(row[1][col])
                    res[var].append(dict(row[1]))
                else: 
                    res[var] = [dict(row[1])]
    return res

# %%
res = search_dict(SF_Data, "typeCodes", typeCodes)
#res.keys()

# %%
#verfication to ensure code is working properly
for k,v in res.items(): 
    print (k, ": ", len(v))
# Out:
# MEDIA :  428
# BUSINESS :  1015
# GOVERNMENT :  2333
# INTER-GOVERNMENTAL ORGANIZATION :  139
# CIVILIAN :  860
# EDUCATION :  555
# POLICE FORCES :  1150
# CRIMINAL :  171
# JUDICIARY :  591
# MILITARY :  352
# LABOR :  212
# AGRICULTURE :  68
# ELITES :  117
# MULTINATIONAL CORPORATION :  101
# LEGISLATURE :  227
# POLITICAL OPPOSITION :  125
# UNIDENTIFIED STATE ACTOR :  9
# STATE INTELLIGENCE :  61
# HUMAN RIGHTS :  26
# RADICAL :  2
# HEALTH :  370
# NON-GOVERNMENTAL ORGANIZATION :  56
# UNALIGNED ARMED FORCES :  35
# REBELS :  21
# REFUGEES :  22
# ENVIRONMENTAL :  6
# SEPARATIST REBELS :  14
# SETTLER :  11
# INTERNATIONAL/TRANSNATIONAL GENERIC :  5
# DEVELOPMENT :  16

# %%
#Put each collection of articles in a Dataframe
list_res = []

for cat in res.values(): 
    #print(cat)
    list_res.append(pd.DataFrame(cat))

# %%
list_res[2] #access the type interested in by changing the variables
# interested in Government actions/types
# this index may change based on the day and number of articles published for TypeCode
# Out:
#        SQLDATE MonthYear  Year FractionDate Actor1Code            Actor1Name  \
# 0     20201004    202010  2020    2020.7507        GOV            GOVERNMENT
# 1     20201004    202010  2020    2020.7507        GOV            GOVERNMENT
# 2     20201004    202010  2020    2020.7507     KENGOV                 KENYA
# 3     20201004    202010  2020    2020.7507     GOVEDU  EDUCATION DEPARTMENT
# 4     20201004    202010  2020    2020.7507        GOV            GOVERNMENT
# ...        ...       ...   ...          ...        ...                   ...
# 2328  20200928    202009  2020    2020.7342        AFR                AFRICA
# 2329  20200928    202009  2020    2020.7342        NaN                   NaN
# 2330  20200927    202009  2020    2020.7315        AFR                AFRICA
# 2331  20200927    202009  2020    2020.7315        COP                DEPUTY
# 2332  20200926    202009  2020    2020.7288        NaN                   NaN
#
#      Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0                  NaN                  NaN              NaN
# 1                  NaN                  NaN              NaN
# 2                  KEN                  NaN              NaN
# 3                  NaN                  NaN              NaN
# 4                  NaN                  NaN              NaN
# ...                ...                  ...              ...
# 2328               AFR                  NaN              NaN
# 2329               NaN                  NaN              NaN
# 2330               AFR                  NaN              NaN
# 2331               NaN                  NaN              NaN
# 2332               NaN                  NaN              NaN
#
#      Actor1Religion1Code  ... Actor2Geo_FeatureID ActionGeo_Type  \
# 0                    NaN  ...                 NaN              4
# 1                    NaN  ...            -1224926              4
# 2                    NaN  ...                 NaN              1
# 3                    NaN  ...                 NaN              1
# 4                    NaN  ...                  SF              1
# ...                  ...  ...                 ...            ...
# 2328                 NaN  ...            -1224926              4
# 2329                 NaN  ...            -1250176              4
# 2330                 NaN  ...                  SF              1
# 2331                 NaN  ...                  SF              1
# 2332                 NaN  ...            -1240261              4
#
#                             ActionGeo_FullName ActionGeo_CountryCode  \
# 0          Durban, KwaZulu-Natal, South Africa                    SF
# 1          Durban, KwaZulu-Natal, South Africa                    SF
# 2                                 South Africa                    SF
# 3                                 South Africa                    SF
# 4                                 South Africa                    SF
# ...                                        ...                   ...
# 2328       Durban, KwaZulu-Natal, South Africa                    SF
# 2329  Kwandengezi, KwaZulu-Natal, South Africa                    SF
# 2330                              South Africa                    SF
# 2331                              South Africa                    SF
# 2332       Johannesburg, Gauteng, South Africa                    SF
#
#      ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long ActionGeo_FeatureID  \
# 0                  SF02        -29.85        31.0167            -1224926
# 1                  SF02        -29.85        31.0167            -1224926
# 2                    SF           -30             26                  SF
# 3                    SF           -30             26                  SF
# 4                    SF           -30             26                  SF
# ...                 ...           ...            ...                 ...
# 2328               SF02        -29.85        31.0167            -1224926
# 2329               SF02      -29.8375        30.7778            -1250176
# 2330                 SF           -30             26                  SF
# 2331                 SF           -30             26                  SF
# 2332               SF06         -26.2        28.0833            -1240261
#
#      DATEADDED                                          SOURCEURL
# 0     20201004  https://www.enca.com/news/emirates-cancels-fli...
# 1     20201004  https://www.enca.com/news/emirates-cancels-fli...
# 2     20201004  https://nation.africa/kenya/news/politics/uhur...
# 3     20201004  https://theconversation.com/what-south-africas...
# 4     20201004  https://mybroadband.co.za/news/government/3700...
# ...        ...                                                ...
# 2328  20200928  https://www.dailysun.co.za/News/cele-visits-ar...
# 2329  20200928  https://ewn.co.za/2020/09/28/4-people-killed-i...
# 2330  20200927  https://citizen.co.za/news/south-africa/politi...
# 2331  20200927  https://citizen.co.za/news/south-africa/politi...
# 2332  20200926  https://citizen.co.za/news/south-africa/insigh...
#
# [2333 rows x 57 columns]

# %% [markdown]
# ### Homework 4: Do some type of analysis with GDELT data. It can be country focused (e.g. Guatemala) or topic focused (e.g. attacks or bilateral agreements)
#
# ### Must write in the first cell what you are interested in. Code must work but results can be garabage. Update the GDELT parameters to get the information you want and then include some type of plot can be a graph or can be a map.
#
# ### Total Points Possible 19

# %%
Gov_data = pd.DataFrame(list_res[2]) #since list_res[0] is hardcoded, this also needs to change based on the day

#particularly interested in Chinese influence in South Africa, so looking to see China as ActionGeo

China_dict = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by country of action
for index, row in Gov_data.iterrows():
    if row["ActionGeo_CountryCode"] in China_dict.keys():
        China_dict[row["ActionGeo_CountryCode"]] += 1 
    else:
        China_dict[row["ActionGeo_CountryCode"]] = 1 

China_dict  #This shows how many events took place in a country
# Out:
# {'SF': 2144,
#  'GM': 9,
#  'ZA': 4,
#  'UK': 8,
#  'ZI': 83,
#  'CH': 8,
#  'CE': 5,
#  'GR': 2,
#  'RS': 5,
#  'UP': 2,
#  'RW': 2,
#  'US': 8,
#  'WA': 2,
#  'CU': 3,
#  'LT': 1,
#  'CF': 2,
#  'MZ': 4,
#  'ET': 3,
#  'BC': 4,
#  'MT': 2,
#  'SA': 2,
#  'NI': 1,
#  'SW': 5,
#  'IR': 6,
#  'IN': 5,
#  'AE': 1,
#  'QA': 4,
#  'AF': 2,
#  'IS': 1,
#  'MP': 1,
#  'GH': 2,
#  'IV': 1,
#  'OD': 1}

# %%
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# code adapted from Session 3 HW

countries = list(China_dict.keys())
instances = list(China_dict.values())

# %%
#Sort from smallest to largest
sorted_countries = sorted(countries, key=lambda x: instances[countries.index(x)])
sorted_instances = sorted(instances)

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_countries, plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_countries, width=0.5, bottom=0,
       top= sorted_instances, color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis

# %%
show(p)
# Out:
#   <div class="bk-root" id="d7aa0808-a47a-4f75-99ae-a724076261da" data-root-id="1002"></div>

# %%
China_dict = {k : v for k,v in China_dict.items() if v > 2}

China_dict

# removed those items from dictionary where there were only one or two instances
# to try to make a little bit better graphic

#code from StackOverflow article
# Out:
# {'SF': 2144,
#  'GM': 9,
#  'ZA': 4,
#  'UK': 8,
#  'ZI': 83,
#  'CH': 8,
#  'CE': 5,
#  'RS': 5,
#  'US': 8,
#  'CU': 3,
#  'MZ': 4,
#  'ET': 3,
#  'BC': 4,
#  'SW': 5,
#  'IR': 6,
#  'IN': 5,
#  'QA': 4}

# %%
countries = list(China_dict.keys())
instances = list(China_dict.values())

# %%
#Sort from smallest to largest
sorted_countries = sorted(countries, key=lambda x: instances[countries.index(x)])
sorted_instances = sorted(instances)

# %%
p = figure(x_range = sorted_countries, plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_countries, width=0.5, bottom=0,
       top= sorted_instances, color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis

# %%
show(p)
# Out:
#   <div class="bk-root" id="baef9ccc-1bd8-467c-9aab-87bb31a7f04c" data-root-id="1100"></div>

# %%
# this doesn't help at all, as South Africa dominates the number of articles
# Did not see China as much as I wanted to at all

# %%
# since that didn't work out, I tried to find the average tone of the articles

AvgTone_dict = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by event type
for index, row in Gov_data.iterrows():
    if row["AvgTone"] in AvgTone_dict.keys():
        AvgTone_dict[row["AvgTone"]] += 1 
    else:
        AvgTone_dict[row["AvgTone"]] = 1 

#AvgTone_dict

# %%
AvgTone_dict = {float(k) : int(v) for k,v in AvgTone_dict.items()}

# %%
Tonelist = []
for key in AvgTone_dict:
    Tonelist.append(key)

# %%
ToneValue = []
for key in AvgTone_dict.keys():
    ToneValue.append(AvgTone_dict[key])

# %%
resultlist = []
for i in range(0, len(Tonelist)):
    resultlist.append(Tonelist[i] * ToneValue[i])
#resultlist
# since some values appeared more than one time, to get an accurate average I needed to 
# multiply the key by the value

# %%
total = sum(resultlist)
avg = total/len(Tonelist)
print(avg) # the average tone of the articles is negative, how surprising
# Out:
# -6.093224013376986
